# %%
#!pip install git+https://github.com/bowang-lab/MedSAM.git

# %%
# %matplotlib widget
from segment_anything import sam_model_registry
from utils.demo import BboxPromptDemo
# Out:
# Warning: Cannot change to a different GUI toolkit: notebook. Using widget instead.

# %%
if __name__ == "__main__":
    MedSAM_CKPT_PATH = "/home/feifeili/experiment/medsam_vit_b.pth"
    device = "cuda:1"
    medsam_model = sam_model_registry['vit_b'](checkpoint=MedSAM_CKPT_PATH)
    medsam_model = medsam_model.to(device)
    medsam_model.eval()
    bbox_prompt_demo = BboxPromptDemo(medsam_model)
    bbox_prompt_demo.show_local("/home/feifeili/experiment/MedSAM/img_demo.png")
# Out:
# Button(description='clear', style=ButtonStyle())
# Canvas(footer_visible=False, header_visible=False, resizable=False, toolbar=Toolbar(toolitems=[('Home', 'Reset…
